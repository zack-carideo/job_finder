# %%
import os , sys , json
import pandas as pd 
import numpy as pd 
from collections import Counter

res_path = 'C://Users//zjc10//OneDrive//Desktop//resources//claude_code//projects//job_finder//job_results.json'

# %%
with open(res_path,'rb'
) as f:
    res = json.load(f)

print([d for d in res[0]])

jobs = [_d['job_name'] for _d in res]
companies = [_d['company'] for _d in res]
urls =  [_d['job_url'] for _d in res]
job_descriptions = [_d['job_description'] for _d in res]


display(Counter(jobs))
display(Counter(companies))
display(Counter(urls))
display(Counter(job_descriptions))
# Out:
# ['job_url', 'job_name', 'company', 'job_description', 'additional_info', 'customized_resume_txt', 'customized_resume_docx', 'customized_cover_letter_txt', 'customized_cover_letter_docx', 'key_requirements']
# Counter({'Engineering Manager': 1,
#          'Director of Data': 1,
#          'Manager, Customer Analytics & Insights': 1,
#          'Manager, Business Intelligence & Accounting Projects': 1,
#          'Decision Science Manager': 1,
#          'Reporting and Analytics Manager': 1,
#          'Risk AI & Engineering': 1,
#          'Quantitative Analytics Manager': 1,
#          'Client Experience Analytics Manager': 1,
#          'Resource Analysis Team Manager': 1,
#          'Model Risk Quant Analytics Manager': 1,
#          'Senior Manager': 1,
#          'Oracle Analytics Cloud & AI, Manager': 1,
#          'Manager': 1,
#          'Performance Marketing Insights Manager': 1})
# Counter({'Deloitte': 3,
#          'Canonical': 1,
#          'Renuity': 1,
# ...
